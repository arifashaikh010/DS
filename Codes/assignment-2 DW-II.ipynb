# %%
#Data Wrangling II
Create an “Academic performance” dataset of students and perform the following operations using 
Python.
1. Scan all variables for missing values and inconsistencies. If there are missing values and/or 
inconsistencies, use any of the suitable techniques to deal with them. 
2. Scan all numeric variables for outliers. If there are outliers, use any of the suitable 
techniques to deal with them. 
3. Apply data transformations on at least one of the variables. The purpose of this 
transformation should be one of the following reasons: to change the scale for better 
understanding of the variable, to convert a non-linear relation into a linear one, or to 
decrease the skewness and convert the distribution into a normal distribution. 
Reason and document your approach properly.

#StudentPerformance.csv

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("StudentPerformance.csv")

# %%
df
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0   female          77             75             60               98
# 1   female          61             85             69               89
# 2     male          69             89             73               83
# 3     male          62             88             78               85
# 4   female          63             93             74               80
# 5   female          77             87             77               86
# 6     male          63             82             75               83
# 7   female          74             87             77               88
# 8     male          67             94             76               75
# 9   female          76             90             66               76
# 10    male          66             90             73               93
# 11    male          70             94             64               93
# 12    male          63             87             62               85
# 13  female          80             78             66               76
# 14  female          66             92             68               75
# 15  female          75             89             68               75
# 16    male          74             87             76               99
# 17  female          64             81             76               90
# 18    male          68             87             70               83
# 19  female          62             88             79               99
# 20    male          74             76             74               77
# 21  female          72             76             78               81
# 22    male          60             88             70               86
# 23    male          64             91             71               93
# 24  female          70             79             79              100
# 25  female          64             86             72               97
# 26    male          69             75             65               99
# 27  female          67             75             65               84
# 28  female          60             88             70               93
# 29    male          77             89             75               96
#
#     placement_offer_count  region
# 0                       2    pune
# 1                       3      na
# 2                       4  nashik
# 3                       1      na
# 4                       1    pune
# 5                       2  nashik
# 6                       1      na
# 7                       0      na
# 8                       2    pune
# 9                       2      na
# 10                      0  nashik
# 11                      1    pune
# 12                      0      na
# 13                      0    pune
# 14                      0  nashik
# 15                      3      na
# 16                      4    pune
# 17                      3     naa
# 18                      4  nashik
# 19                      2    pune
# 20                      2      na
# 21                      4    pune
# 22                      4    pune
# 23                      1  nashik
# 24                      0      na
# 25                      2    pune
# 26                      3      na
# 27                      3  nashik
# 28                      1    pune
# 29                      1     NaN

# %% [markdown]
# #### checking missing values using notnull()

# %%
df.notnull()
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0     True        True           True           True             True
# 1     True        True           True           True             True
# 2     True        True           True           True             True
# 3     True        True           True           True             True
# 4     True        True           True           True             True
# 5     True        True           True           True             True
# 6     True        True           True           True             True
# 7     True        True           True           True             True
# 8     True        True           True           True             True
# 9     True        True           True           True             True
# 10    True        True           True           True             True
# 11    True        True           True           True             True
# 12    True        True           True           True             True
# 13    True        True           True           True             True
# 14    True        True           True           True             True
# 15    True        True           True           True             True
# 16    True        True           True           True             True
# 17    True        True           True           True             True
# 18    True        True           True           True             True
# 19    True        True           True           True             True
# 20    True        True           True           True             True
# 21    True        True           True           True             True
# 22    True        True           True           True             True
# 23    True        True           True           True             True
# 24    True        True           True           True             True
# 25    True        True           True           True             True
# 26    True        True           True           True             True
# 27    True        True           True           True             True
# 28    True        True           True           True             True
# 29    True        True           True           True             True
#
#     placement_offer_count  region
# 0                    True    True
# 1                    True    True
# 2                    True    True
# 3                    True    True
# 4                    True    True
# 5                    True    True
# 6                    True    True
# 7                    True    True
# 8                    True    True
# 9                    True    True
# 10                   True    True
# 11                   True    True
# 12                   True    True
# 13                   True    True
# 14                   True    True
# 15                   True    True
# 16                   True    True
# 17                   True    True
# 18                   True    True
# 19                   True    True
# 20                   True    True
# 21                   True    True
# 22                   True    True
# 23                   True    True
# 24                   True    True
# 25                   True    True
# 26                   True    True
# 27                   True    True
# 28                   True    True
# 29                   True   False

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['gender']=le.fit_transform(df['gender'])
newdf=df

# %%
df
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0        0          77             75             60               98
# 1        0          61             85             69               89
# 2        1          69             89             73               83
# 3        1          62             88             78               85
# 4        0          63             93             74               80
# 5        0          77             87             77               86
# 6        1          63             82             75               83
# 7        0          74             87             77               88
# 8        1          67             94             76               75
# 9        0          76             90             66               76
# 10       1          66             90             73               93
# 11       1          70             94             64               93
# 12       1          63             87             62               85
# 13       0          80             78             66               76
# 14       0          66             92             68               75
# 15       0          75             89             68               75
# 16       1          74             87             76               99
# 17       0          64             81             76               90
# 18       1          68             87             70               83
# 19       0          62             88             79               99
# 20       1          74             76             74               77
# 21       0          72             76             78               81
# 22       1          60             88             70               86
# 23       1          64             91             71               93
# 24       0          70             79             79              100
# 25       0          64             86             72               97
# 26       1          69             75             65               99
# 27       0          67             75             65               84
# 28       0          60             88             70               93
# 29       1          77             89             75               96
#
#     placement_offer_count  region
# 0                       2    pune
# 1                       3      na
# 2                       4  nashik
# 3                       1      na
# 4                       1    pune
# 5                       2  nashik
# 6                       1      na
# 7                       0      na
# 8                       2    pune
# 9                       2      na
# 10                      0  nashik
# 11                      1    pune
# 12                      0      na
# 13                      0    pune
# 14                      0  nashik
# 15                      3      na
# 16                      4    pune
# 17                      3     naa
# 18                      4  nashik
# 19                      2    pune
# 20                      2      na
# 21                      4    pune
# 22                      4    pune
# 23                      1  nashik
# 24                      0      na
# 25                      2    pune
# 26                      3      na
# 27                      3  nashik
# 28                      1    pune
# 29                      1     NaN

# %% [markdown]
# ### Filling missing values using dropna(), fillna(), replace()

# %%
missing_values = ["na"]

# %%
df=pd.read_csv("StudentPerformance.csv", na_values=missing_values)

# %%
df
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0   female          77             75             60               98
# 1   female          61             85             69               89
# 2     male          69             89             73               83
# 3     male          62             88             78               85
# 4   female          63             93             74               80
# 5   female          77             87             77               86
# 6     male          63             82             75               83
# 7   female          74             87             77               88
# 8     male          67             94             76               75
# 9   female          76             90             66               76
# 10    male          66             90             73               93
# 11    male          70             94             64               93
# 12    male          63             87             62               85
# 13  female          80             78             66               76
# 14  female          66             92             68               75
# 15  female          75             89             68               75
# 16    male          74             87             76               99
# 17  female          64             81             76               90
# 18    male          68             87             70               83
# 19  female          62             88             79               99
# 20    male          74             76             74               77
# 21  female          72             76             78               81
# 22    male          60             88             70               86
# 23    male          64             91             71               93
# 24  female          70             79             79              100
# 25  female          64             86             72               97
# 26    male          69             75             65               99
# 27  female          67             75             65               84
# 28  female          60             88             70               93
# 29    male          77             89             75               96
#
#     placement_offer_count  region
# 0                       2    pune
# 1                       3     NaN
# 2                       4  nashik
# 3                       1     NaN
# 4                       1    pune
# 5                       2  nashik
# 6                       1     NaN
# 7                       0     NaN
# 8                       2    pune
# 9                       2     NaN
# 10                      0  nashik
# 11                      1    pune
# 12                      0     NaN
# 13                      0    pune
# 14                      0  nashik
# 15                      3     NaN
# 16                      4    pune
# 17                      3     naa
# 18                      4  nashik
# 19                      2    pune
# 20                      2     NaN
# 21                      4    pune
# 22                      4    pune
# 23                      1  nashik
# 24                      0     NaN
# 25                      2    pune
# 26                      3     NaN
# 27                      3  nashik
# 28                      1    pune
# 29                      1     NaN

# %% [markdown]
# #### filling null values with a single value

# %%
ndf=df
ndf.fillna(0)
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0   female          77             75             60               98
# 1   female          61             85             69               89
# 2     male          69             89             73               83
# 3     male          62             88             78               85
# 4   female          63             93             74               80
# 5   female          77             87             77               86
# 6     male          63             82             75               83
# 7   female          74             87             77               88
# 8     male          67             94             76               75
# 9   female          76             90             66               76
# 10    male          66             90             73               93
# 11    male          70             94             64               93
# 12    male          63             87             62               85
# 13  female          80             78             66               76
# 14  female          66             92             68               75
# 15  female          75             89             68               75
# 16    male          74             87             76               99
# 17  female          64             81             76               90
# 18    male          68             87             70               83
# 19  female          62             88             79               99
# 20    male          74             76             74               77
# 21  female          72             76             78               81
# 22    male          60             88             70               86
# 23    male          64             91             71               93
# 24  female          70             79             79              100
# 25  female          64             86             72               97
# 26    male          69             75             65               99
# 27  female          67             75             65               84
# 28  female          60             88             70               93
# 29    male          77             89             75               96
#
#     placement_offer_count  region
# 0                       2    pune
# 1                       3       0
# 2                       4  nashik
# 3                       1       0
# 4                       1    pune
# 5                       2  nashik
# 6                       1       0
# 7                       0       0
# 8                       2    pune
# 9                       2       0
# 10                      0  nashik
# 11                      1    pune
# 12                      0       0
# 13                      0    pune
# 14                      0  nashik
# 15                      3       0
# 16                      4    pune
# 17                      3     naa
# 18                      4  nashik
# 19                      2    pune
# 20                      2       0
# 21                      4    pune
# 22                      4    pune
# 23                      1  nashik
# 24                      0       0
# 25                      2    pune
# 26                      3       0
# 27                      3  nashik
# 28                      1    pune
# 29                      1       0

# %% [markdown]
# #### filling null values using replace()

# %%
ndf.replace(to_replace=np.nan, value=-1)
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0   female          77             75             60               98
# 1   female          61             85             69               89
# 2     male          69             89             73               83
# 3     male          62             88             78               85
# 4   female          63             93             74               80
# 5   female          77             87             77               86
# 6     male          63             82             75               83
# 7   female          74             87             77               88
# 8     male          67             94             76               75
# 9   female          76             90             66               76
# 10    male          66             90             73               93
# 11    male          70             94             64               93
# 12    male          63             87             62               85
# 13  female          80             78             66               76
# 14  female          66             92             68               75
# 15  female          75             89             68               75
# 16    male          74             87             76               99
# 17  female          64             81             76               90
# 18    male          68             87             70               83
# 19  female          62             88             79               99
# 20    male          74             76             74               77
# 21  female          72             76             78               81
# 22    male          60             88             70               86
# 23    male          64             91             71               93
# 24  female          70             79             79              100
# 25  female          64             86             72               97
# 26    male          69             75             65               99
# 27  female          67             75             65               84
# 28  female          60             88             70               93
# 29    male          77             89             75               96
#
#     placement_offer_count  region
# 0                       2    pune
# 1                       3      -1
# 2                       4  nashik
# 3                       1      -1
# 4                       1    pune
# 5                       2  nashik
# 6                       1      -1
# 7                       0      -1
# 8                       2    pune
# 9                       2      -1
# 10                      0  nashik
# 11                      1    pune
# 12                      0      -1
# 13                      0    pune
# 14                      0  nashik
# 15                      3      -1
# 16                      4    pune
# 17                      3     naa
# 18                      4  nashik
# 19                      2    pune
# 20                      2      -1
# 21                      4    pune
# 22                      4    pune
# 23                      1  nashik
# 24                      0      -1
# 25                      2    pune
# 26                      3      -1
# 27                      3  nashik
# 28                      1    pune
# 29                      1      -1

# %% [markdown]
# #### deleting null values using dropna() method

# %%
ndf.dropna()
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0   female          77             75             60               98
# 2     male          69             89             73               83
# 4   female          63             93             74               80
# 5   female          77             87             77               86
# 8     male          67             94             76               75
# 10    male          66             90             73               93
# 11    male          70             94             64               93
# 13  female          80             78             66               76
# 14  female          66             92             68               75
# 16    male          74             87             76               99
# 17  female          64             81             76               90
# 18    male          68             87             70               83
# 19  female          62             88             79               99
# 21  female          72             76             78               81
# 22    male          60             88             70               86
# 23    male          64             91             71               93
# 25  female          64             86             72               97
# 27  female          67             75             65               84
# 28  female          60             88             70               93
#
#     placement_offer_count  region
# 0                       2    pune
# 2                       4  nashik
# 4                       1    pune
# 5                       2  nashik
# 8                       2    pune
# 10                      0  nashik
# 11                      1    pune
# 13                      0    pune
# 14                      0  nashik
# 16                      4    pune
# 17                      3     naa
# 18                      4  nashik
# 19                      2    pune
# 21                      4    pune
# 22                      4    pune
# 23                      1  nashik
# 25                      2    pune
# 27                      3  nashik
# 28                      1    pune

# %% [markdown]
# ## Identification and handling outliers

# %%
#Go to line

# %%
df
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0   female          77             75             60               98
# 1   female          61             85             69               89
# 2     male          69             89             73               83
# 3     male          62             88             78               85
# 4   female          63             93             74               80
# 5   female          77             87             77               86
# 6     male          63             82             75               83
# 7   female          74             87             77               88
# 8     male          67             94             76               75
# 9   female          76             90             66               76
# 10    male          66             90             73               93
# 11    male          70             94             64               93
# 12    male          63             87             62               85
# 13  female          80             78             66               76
# 14  female          66             92             68               75
# 15  female          75             89             68               75
# 16    male          74             87             76               99
# 17  female          64             81             76               90
# 18    male          68             87             70               83
# 19  female          62             88             79               99
# 20    male          74             76             74               77
# 21  female          72             76             78               81
# 22    male          60             88             70               86
# 23    male          64             91             71               93
# 24  female          70             79             79              100
# 25  female          64             86             72               97
# 26    male          69             75             65               99
# 27  female          67             75             65               84
# 28  female          60             88             70               93
# 29    male          77             89             75               96
#
#     placement_offer_count  region
# 0                       2    pune
# 1                       3     NaN
# 2                       4  nashik
# 3                       1     NaN
# 4                       1    pune
# 5                       2  nashik
# 6                       1     NaN
# 7                       0     NaN
# 8                       2    pune
# 9                       2     NaN
# 10                      0  nashik
# 11                      1    pune
# 12                      0     NaN
# 13                      0    pune
# 14                      0  nashik
# 15                      3     NaN
# 16                      4    pune
# 17                      3     naa
# 18                      4  nashik
# 19                      2    pune
# 20                      2     NaN
# 21                      4    pune
# 22                      4    pune
# 23                      1  nashik
# 24                      0     NaN
# 25                      2    pune
# 26                      3     NaN
# 27                      3  nashik
# 28                      1    pune
# 29                      1     NaN

# %% [markdown]
# #### detecting outlier using boxplot

# %%
col=['math_score','reading_score','writing_score','placement_score']
df.boxplot(col)
# Out:
# <AxesSubplot:>

# %%
print(np.where(df['math_score']>90))
print(np.where(df['reading_score']<25))
print(np.where(df['writing_score']<30))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %% [markdown]
# #### detecting outlier using scatterplot

# %%
import matplotlib.pyplot as plt

# %%
fig, ax=plt.subplots(figsize=(18,10))
ax.scatter(df['placement_score'],df['placement_offer_count'])
plt.show()

# %% [markdown]
# #### Detecting outliers using Z-Score:

# %%
import numpy as np
from scipy import stats

# %%
z = np.abs(stats.zscore(df['math_score']))

# %%
print(z)
# Out:
# 0     1.471070
# 1     1.287186
# 2     0.091942
# 3     1.114795
# 4     0.942404
# 5     1.471070
# 6     0.942404
# 7     0.953897
# 8     0.252840
# 9     1.298679
# 10    0.425231
# 11    0.264333
# 12    0.942404
# 13    1.988243
# 14    0.425231
# 15    1.126288
# 16    0.953897
# 17    0.770013
# 18    0.080449
# 19    1.114795
# 20    0.953897
# 21    0.609115
# 22    1.459577
# 23    0.770013
# 24    0.264333
# 25    0.770013
# 26    0.091942
# 27    0.252840
# 28    1.459577
# 29    1.471070
# Name: math_score, dtype: float64

# %%
threshold=0.18
sample_outliers = np.where(z<threshold)

# %%
sample_outliers
# Out:
# (array([ 2, 18, 26], dtype=int64),)

# %% [markdown]
# ####  Detecting outliers using Inter Quantile Range(IQR):

# %%
sorted_rscore= sorted(df['reading_score'])
sorted_rscore
# Out:
# [75,
#  75,
#  75,
#  76,
#  76,
#  78,
#  79,
#  81,
#  82,
#  85,
#  86,
#  87,
#  87,
#  87,
#  87,
#  87,
#  88,
#  88,
#  88,
#  88,
#  89,
#  89,
#  89,
#  90,
#  90,
#  91,
#  92,
#  93,
#  94,
#  94]

# %%
q1 = np.percentile(sorted_rscore, 25)
q3 = np.percentile(sorted_rscore, 75)
print(q1,q3)
# Out:
# 81.25 89.0

# %%
IQR = q3-q1

# %%
lwr_bound = q1-(1.5*IQR)
upr_bound = q3+(1.5*IQR)
print(lwr_bound, upr_bound)
# Out:
# 69.625 100.625

# %% [markdown]
# ### handling outliers

# %% [markdown]
# #### trimming/removing the outliers

# %%
new_df = df
for i in sample_outliers:
    new_df.drop(i,inplace=True)
new_df
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0   female          77             75             60               98
# 1   female          61             85             69               89
# 3     male          62             88             78               85
# 4   female          63             93             74               80
# 5   female          77             87             77               86
# 6     male          63             82             75               83
# 7   female          74             87             77               88
# 8     male          67             94             76               75
# 9   female          76             90             66               76
# 10    male          66             90             73               93
# 11    male          70             94             64               93
# 12    male          63             87             62               85
# 13  female          80             78             66               76
# 14  female          66             92             68               75
# 15  female          75             89             68               75
# 16    male          74             87             76               99
# 17  female          64             81             76               90
# 19  female          62             88             79               99
# 20    male          74             76             74               77
# 21  female          72             76             78               81
# 22    male          60             88             70               86
# 23    male          64             91             71               93
# 24  female          70             79             79              100
# 25  female          64             86             72               97
# 27  female          67             75             65               84
# 28  female          60             88             70               93
# 29    male          77             89             75               96
#
#     placement_offer_count  region
# 0                       2    pune
# 1                       3     NaN
# 3                       1     NaN
# 4                       1    pune
# 5                       2  nashik
# 6                       1     NaN
# 7                       0     NaN
# 8                       2    pune
# 9                       2     NaN
# 10                      0  nashik
# 11                      1    pune
# 12                      0     NaN
# 13                      0    pune
# 14                      0  nashik
# 15                      3     NaN
# 16                      4    pune
# 17                      3     naa
# 19                      2    pune
# 20                      2     NaN
# 21                      4    pune
# 22                      4    pune
# 23                      1  nashik
# 24                      0     NaN
# 25                      2    pune
# 27                      3  nashik
# 28                      1    pune
# 29                      1     NaN

# %% [markdown]
# #### quantile based flooring and capping

# %%
df_stud=df
ninetieth_percentile=np.percentile(df_stud['math_score'],90)
b=np.where(df_stud['math_score']>ninetieth_percentile,
ninetieth_percentile,df_stud['math_score'])
print("new Array: ",b)
# Out:
# new Array:  [77. 61. 62. 63. 77. 63. 74. 67. 76. 66. 70. 63. 77. 66. 75. 74. 64. 62.
#  74. 72. 60. 64. 70. 64. 67. 60. 77.]

# %%
df_stud.insert(1,"m_score",b,True)
df_stud
# Out:
#     gender  m_score  math_score  reading_score  writing_score  \
# 0   female     77.0          77             75             60
# 1   female     61.0          61             85             69
# 3     male     62.0          62             88             78
# 4   female     63.0          63             93             74
# 5   female     77.0          77             87             77
# 6     male     63.0          63             82             75
# 7   female     74.0          74             87             77
# 8     male     67.0          67             94             76
# 9   female     76.0          76             90             66
# 10    male     66.0          66             90             73
# 11    male     70.0          70             94             64
# 12    male     63.0          63             87             62
# 13  female     77.0          80             78             66
# 14  female     66.0          66             92             68
# 15  female     75.0          75             89             68
# 16    male     74.0          74             87             76
# 17  female     64.0          64             81             76
# 19  female     62.0          62             88             79
# 20    male     74.0          74             76             74
# 21  female     72.0          72             76             78
# 22    male     60.0          60             88             70
# 23    male     64.0          64             91             71
# 24  female     70.0          70             79             79
# 25  female     64.0          64             86             72
# 27  female     67.0          67             75             65
# 28  female     60.0          60             88             70
# 29    male     77.0          77             89             75
#
#     placement_score  placement_offer_count  region
# 0                98                      2    pune
# 1                89                      3     NaN
# 3                85                      1     NaN
# 4                80                      1    pune
# 5                86                      2  nashik
# 6                83                      1     NaN
# 7                88                      0     NaN
# 8                75                      2    pune
# 9                76                      2     NaN
# 10               93                      0  nashik
# 11               93                      1    pune
# 12               85                      0     NaN
# 13               76                      0    pune
# 14               75                      0  nashik
# 15               75                      3     NaN
# 16               99                      4    pune
# 17               90                      3     naa
# 19               99                      2    pune
# 20               77                      2     NaN
# 21               81                      4    pune
# 22               86                      4    pune
# 23               93                      1  nashik
# 24              100                      0     NaN
# 25               97                      2    pune
# 27               84                      3  nashik
# 28               93                      1    pune
# 29               96                      1     NaN

# %% [markdown]
# #### mean/median imputation

# %%
col=['reading_score']

# %%
df.boxplot(col)
# Out:
# <AxesSubplot:>

# %%
###optional uper ka 2

# %%
median = np.median(sorted_rscore)
median
# Out:
# 87.0

# %%
refined_df=df

# %%
refined_df['reading_score'] = np.where(refined_df['reading_score'] 
>upr_bound, median,refined_df['reading_score'])

# %%
refined_df
# Out:
#     gender  m_score  math_score  reading_score  writing_score  \
# 0   female     77.0          77           75.0             60
# 1   female     61.0          61           85.0             69
# 3     male     62.0          62           88.0             78
# 4   female     63.0          63           93.0             74
# 5   female     77.0          77           87.0             77
# 6     male     63.0          63           82.0             75
# 7   female     74.0          74           87.0             77
# 8     male     67.0          67           94.0             76
# 9   female     76.0          76           90.0             66
# 10    male     66.0          66           90.0             73
# 11    male     70.0          70           94.0             64
# 12    male     63.0          63           87.0             62
# 13  female     77.0          80           78.0             66
# 14  female     66.0          66           92.0             68
# 15  female     75.0          75           89.0             68
# 16    male     74.0          74           87.0             76
# 17  female     64.0          64           81.0             76
# 19  female     62.0          62           88.0             79
# 20    male     74.0          74           76.0             74
# 21  female     72.0          72           76.0             78
# 22    male     60.0          60           88.0             70
# 23    male     64.0          64           91.0             71
# 24  female     70.0          70           79.0             79
# 25  female     64.0          64           86.0             72
# 27  female     67.0          67           75.0             65
# 28  female     60.0          60           88.0             70
# 29    male     77.0          77           89.0             75
#
#     placement_score  placement_offer_count  region
# 0                98                      2    pune
# 1                89                      3     NaN
# 3                85                      1     NaN
# 4                80                      1    pune
# 5                86                      2  nashik
# 6                83                      1     NaN
# 7                88                      0     NaN
# 8                75                      2    pune
# 9                76                      2     NaN
# 10               93                      0  nashik
# 11               93                      1    pune
# 12               85                      0     NaN
# 13               76                      0    pune
# 14               75                      0  nashik
# 15               75                      3     NaN
# 16               99                      4    pune
# 17               90                      3     naa
# 19               99                      2    pune
# 20               77                      2     NaN
# 21               81                      4    pune
# 22               86                      4    pune
# 23               93                      1  nashik
# 24              100                      0     NaN
# 25               97                      2    pune
# 27               84                      3  nashik
# 28               93                      1    pune
# 29               96                      1     NaN

# %%
refined_df['reading_score'] = np.where(refined_df['reading_score'] 
<lwr_bound, median,refined_df['reading_score'])
refined_df
# Out:
#     gender  m_score  math_score  reading_score  writing_score  \
# 0   female     77.0          77           75.0             60
# 1   female     61.0          61           85.0             69
# 3     male     62.0          62           88.0             78
# 4   female     63.0          63           93.0             74
# 5   female     77.0          77           87.0             77
# 6     male     63.0          63           82.0             75
# 7   female     74.0          74           87.0             77
# 8     male     67.0          67           94.0             76
# 9   female     76.0          76           90.0             66
# 10    male     66.0          66           90.0             73
# 11    male     70.0          70           94.0             64
# 12    male     63.0          63           87.0             62
# 13  female     77.0          80           78.0             66
# 14  female     66.0          66           92.0             68
# 15  female     75.0          75           89.0             68
# 16    male     74.0          74           87.0             76
# 17  female     64.0          64           81.0             76
# 19  female     62.0          62           88.0             79
# 20    male     74.0          74           76.0             74
# 21  female     72.0          72           76.0             78
# 22    male     60.0          60           88.0             70
# 23    male     64.0          64           91.0             71
# 24  female     70.0          70           79.0             79
# 25  female     64.0          64           86.0             72
# 27  female     67.0          67           75.0             65
# 28  female     60.0          60           88.0             70
# 29    male     77.0          77           89.0             75
#
#     placement_score  placement_offer_count  region
# 0                98                      2    pune
# 1                89                      3     NaN
# 3                85                      1     NaN
# 4                80                      1    pune
# 5                86                      2  nashik
# 6                83                      1     NaN
# 7                88                      0     NaN
# 8                75                      2    pune
# 9                76                      2     NaN
# 10               93                      0  nashik
# 11               93                      1    pune
# 12               85                      0     NaN
# 13               76                      0    pune
# 14               75                      0  nashik
# 15               75                      3     NaN
# 16               99                      4    pune
# 17               90                      3     naa
# 19               99                      2    pune
# 20               77                      2     NaN
# 21               81                      4    pune
# 22               86                      4    pune
# 23               93                      1  nashik
# 24              100                      0     NaN
# 25               97                      2    pune
# 27               84                      3  nashik
# 28               93                      1    pune
# 29               96                      1     NaN

# %%
col = ['reading_score']
refined_df.boxplot(col)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Data Transformation

# %%
df
# Out:
#     gender  m_score  math_score  reading_score  writing_score  \
# 0   female     77.0          77           75.0             60
# 1   female     61.0          61           85.0             69
# 3     male     62.0          62           88.0             78
# 4   female     63.0          63           93.0             74
# 5   female     77.0          77           87.0             77
# 6     male     63.0          63           82.0             75
# 7   female     74.0          74           87.0             77
# 8     male     67.0          67           94.0             76
# 9   female     76.0          76           90.0             66
# 10    male     66.0          66           90.0             73
# 11    male     70.0          70           94.0             64
# 12    male     63.0          63           87.0             62
# 13  female     77.0          80           78.0             66
# 14  female     66.0          66           92.0             68
# 15  female     75.0          75           89.0             68
# 16    male     74.0          74           87.0             76
# 17  female     64.0          64           81.0             76
# 19  female     62.0          62           88.0             79
# 20    male     74.0          74           76.0             74
# 21  female     72.0          72           76.0             78
# 22    male     60.0          60           88.0             70
# 23    male     64.0          64           91.0             71
# 24  female     70.0          70           79.0             79
# 25  female     64.0          64           86.0             72
# 27  female     67.0          67           75.0             65
# 28  female     60.0          60           88.0             70
# 29    male     77.0          77           89.0             75
#
#     placement_score  placement_offer_count  region
# 0                98                      2    pune
# 1                89                      3     NaN
# 3                85                      1     NaN
# 4                80                      1    pune
# 5                86                      2  nashik
# 6                83                      1     NaN
# 7                88                      0     NaN
# 8                75                      2    pune
# 9                76                      2     NaN
# 10               93                      0  nashik
# 11               93                      1    pune
# 12               85                      0     NaN
# 13               76                      0    pune
# 14               75                      0  nashik
# 15               75                      3     NaN
# 16               99                      4    pune
# 17               90                      3     naa
# 19               99                      2    pune
# 20               77                      2     NaN
# 21               81                      4    pune
# 22               86                      4    pune
# 23               93                      1  nashik
# 24              100                      0     NaN
# 25               97                      2    pune
# 27               84                      3  nashik
# 28               93                      1    pune
# 29               96                      1     NaN

# %%
import matplotlib.pyplot as plt
new_df['math_score'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['log_math'] = np.log10(df['math_score'])

# %%
df['log_math'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#---------------------------------------------------------------------------------------------------------------

# %%
#Outliers Detection

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (9, 6)
df_list = ['math_score', 'reading_score', 'writing_score', 'placement_score', 'placement_offer_count'] 
fig, axes = plt.subplots(2, 3)
fig.set_dpi(120)

count=0
for r in range(2):
    for c in range(3):
        df[df_list[count]].plot(kind = 'box', ax=axes[r,c])
        count+=1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25188\792931691.py in <module>
#       8 for r in range(2):
#       9     for c in range(3):
# ---> 10         df[df_list[count]].plot(kind = 'box', ax=axes[r,c])
#      11         count+=1
#
# IndexError: list index out of range
